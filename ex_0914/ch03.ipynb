# %%
#!pip --version
# Out:
# pip 25.0.1 from D:\kingSJ\hanwha_0902\ex_0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install dotenv

# %%
from dotenv import load_dotenv

load_dotenv()  # .env 파일 로드
# Out:
# True

# %%
import os

print(f"키 값은 : {os.environ['OPENAI_API_KEY'][:8]}")
# Out:
# 키 값은 : sk-proj-
