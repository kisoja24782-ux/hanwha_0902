# %% [markdown]
# ### 출력 파서를 체인에 연결
# - chain = prompt | model | output_parser

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요")
model = ChatOpenAI()

input = {"topic": "인공지능 모델의 학습 원리"}

# %%
print(prompt)
print(input)
# Out:
# input_variables=['topic'] input_types={} partial_variables={} template='{topic} 에 대해 쉽게 설명해주세요'
# {'topic': '인공지능 모델의 학습 원리'}

# %%
output_parser = StrOutputParser()
output_parser
# Out:
# StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
input = {"topic": "인공지능 모델의 학습원리"}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 데이터를 입력으로 받아들이고 특정한 패턴이나 규칙을 학습하여 문제를 해결하는 과정입니다. 이러한 과정을 위해서 모델은 많은 양의 데이터를 사용하여 학습을 진행하고, 데이터의 특징을 추출하고 분석합니다. \n\n모델은 학습된 데이터를 사용하여 특정한 패턴이나 규칙을 찾아내어 이를 바탕으로 새로운 데이터에 대한 예측이나 결정을 내립니다. 이러한 방법으로 인공지능 모델은 문제를 해결하고 목표를 달성하며, 그 과정에서 데이터의 특성이나 패턴을 이해하고 적용할 수 있게 됩니다.\n\n쉽게 말하면, 인공지능 모델은 데이터를 통해 학습하여 패턴을 파악하고 이를 바탕으로 새로운 데이터에 대한 예측이나 결정을 내리는 과정을 거치게 됩니다. 이를 통해 모델은 문제를 해결하고 목표를 달성하는데 도움을 줍니다.'

# %%
template = """
당신은 영어를 가르치는 10년차 영어 선생님입니다.
주어진 상황에 맞는 영어 회화를 작성해 주세요
양식은 [FORMAT]을 찹고하여 작성해 주세요

#상황: {question}
# FORMAT : 
- 영어 회화:
- 한글 해석:
"""

# %%
prompt = PromptTemplate.from_template(template)

model = ChatOpenAI(model="gpt-4o-mini")

output_parser = StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
print(chain.invoke({"question":"저는 식당에 가서 음식을 주문하고 싶어요"}))
# Out:
# - 영어 회화:
#   **Customer:** Hi, could I see the menu, please?
#   **Waiter:** Of course! Here you go.
#   **Customer:** Thank you! What do you recommend?
#   **Waiter:** Our special today is grilled salmon with a side of asparagus.
#   **Customer:** That sounds great! I’ll have that, please.
#   **Waiter:** Would you like anything to drink?
#   **Customer:** Yes, I’ll have a glass of water, please.
#   **Waiter:** Sure! I’ll be right back with your order.
#
# - 한글 해석:
#   **고객:** 안녕하세요, 메뉴 좀 보여주실 수 있나요?
#   **웨이터:** 물론입니다! 여기 있습니다.
#   **고객:** 감사합니다! 추천할 만한 것이 있나요?
#   **웨이터:** 오늘의 특별 메뉴는 구운 연어와 아스파라거스입니다.
#   **고객:** 좋은 것 같아요! 그걸로 주세요.
#   **웨이터:** 음료는 무엇을 드릴까요?
#   **고객:** 네, 물 한 잔 주세요.
#   **웨이터:** 알겠습니다! 주문하신 것을 곧 가져다 드리겠습니다.

# %%
from langchain_teddynote.messages import stream_response

answer = chain.stream({"question":"미국에서 피자 주문"})

print(stream_response(answer))
# Out:
# - 영어 회화:
#    Customer: Hi, I'd like to order a pizza, please.
#    Server: Sure! What size would you like?
#    Customer: I’d like a large pizza.
#    Server: What toppings do you want?
#    Customer: I’d like pepperoni and mushrooms, please.
#    Server: Would you like any drinks with that?
#    Customer: Yes, I’ll take a Coke, please.
#    Server: Great! That will be $25. Do you want it for delivery or pick-up?
#    Customer: I’ll pick it up.
#    Server: Perfect! It will be ready in about 20 minutes.
#
# - 한글 해석:
#    고객: 안녕하세요, 피자 하나 주문하고 싶어요.
#    서버: 물론이죠! 어떤 사이즈로 하시겠어요?
#    고객: 대형 피자로 주세요.
#    서버: 어떤 토핑을 원하시나요?
#    고객: 페퍼로니와 버섯으로 주세요.
#    서버: 음료수도 필요하신가요?
#    고객: 네, 콜라 하나 주세요.
#    서버: 좋습니다! 총 25달러입니다. 배달로 하시겠어요, 아니면 픽업으로 하시겠어요?
#    고객: 픽업으로 할게요.
#    서버: 완벽합니다! 약 20분 후에 준비될 거예요.None
