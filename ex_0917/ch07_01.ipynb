# %% [markdown]
# ### 다양한 LLM 활용 방법과 API 키 가져오기

# %%
# !python --version
# Out:
# Python 3.12.10

# %%
# %pip install langchain langchain-classic langchain-openai langchain-chroma langchain-teddynote python-dotenv pandas jupyter ipykernel

# %% [markdown]
# ### OpenAI 모델

# %%
import os

from langchain_teddynote.messages import stream_response
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_teddynote import logging

load_dotenv()
logging.langsmith("test0914")


print("OpenAI 키 로드됨 : ", bool(os.getenv("OPENAI_API_KEY")))
print("LangSmith 키 로드됨 : ", bool(os.getenv("LANGSMITH_API_KEY")))
print("LangSmith 프로젝트 : ", os.getenv("LANGSMITH_PROJECT"))
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test0914
# OpenAI 키 로드됨 :  True
# LangSmith 키 로드됨 :  True
# LangSmith 프로젝트 :  test0914

# %%
gpt = ChatOpenAI(temperature=0, model="gpt-4o-mini")

answer = gpt.stream("사랑이 뭔가요?")
stream_response(answer)
# Out:
# 사랑은 복잡하고 다면적인 감정으로, 사람들 간의 깊은 유대감이나 애정을 의미합니다. 사랑은 여러 형태로 나타날 수 있으며, 가족 간의 사랑, 친구 간의 사랑, 연인 간의 사랑 등 다양한 관계에서 경험할 수 있습니다.
#
# 사랑은 종종 기쁨, 행복, 헌신, 이해, 희생 등의 감정을 동반하며, 때로는 고통이나 갈등을 수반하기도 합니다. 사랑은 사람의 삶에 큰 영향을 미치며, 개인의 정체성과 행복에 중요한 역할을 합니다.
#
# 사랑의 정의는 문화, 개인의 경험, 가치관에 따라 다를 수 있으며, 각 사람마다 사랑을 느끼고 표현하는 방식이 다릅니다.

# %%
# %pip install --upgrade pip

# %%
# %pip install langchain-anthropic

# %% [markdown]
# Claude  크레딧 충전해야함

# %%
from langchain_anthropic import ChatAnthropic

anthropic = ChatAnthropic(model="claude-sonnet-5")

answer = anthropic.stream("사랑이 뭔가요 ?")

stream_response(answer)
